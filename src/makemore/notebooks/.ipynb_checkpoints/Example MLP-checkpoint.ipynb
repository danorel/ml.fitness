# %%
import numpy as np 
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F

# %%
with open('names.txt', 'r') as f:
    names = f.read().splitlines()
    chars = sorted(set((char for name in names for char in name)))

# %%
CHAR_SEP = '.'

# %%
SEQ_SIZE = 3
VOC_SIZE = 27
EMB_SIZE = 10
HID_SIZE = 200
BCH_SIZE = 128

# %%
i2c    = {i: c for i, c in enumerate(chars, 1)}
i2c[0] = CHAR_SEP
c2i    = {c: i for i, c in i2c.items()}

# %%
def get_dataset(sequence_size: int = 3, verbose=True):
    xs = []
    ys = []
    
    for i, name in enumerate(names):
        if verbose:
            print(f"name[{i}]: {name}")
        name += CHAR_SEP
        x = ''.join([CHAR_SEP] * SEQ_SIZE)
        for j in range(len(name)):
            y = name[j]
            xs.append([c2i[c] for c in x])
            ys.append(c2i[y])
            if verbose:
                print(f"{x} -> {y}")
            x = f"{x[1:]}{name[j]}"
    
    return torch.tensor(xs), torch.tensor(ys)

xs, ys = get_dataset(SEQ_SIZE, verbose=False)
xs.shape
# Out:
# torch.Size([228146, 3])

# %%
def split_dataset(xs, ys, tr=0.8, vl=0.1, ts=0.1):
    assert len(xs) == len(ys)
    assert abs(tr + vl + ts - 1.0) < 1e-6

    n = len(xs)

    n_tr = int(tr * n)
    n_vl = int(vl * n)

    xs_tr = xs[:n_tr]
    ys_tr = ys[:n_tr]

    xs_vl = xs[n_tr:n_tr + n_vl]
    ys_vl = ys[n_tr:n_tr + n_vl]

    xs_ts = xs[n_tr + n_vl:]
    ys_ts = ys[n_tr + n_vl:]

    return xs_tr, ys_tr, xs_vl, ys_vl, xs_ts, ys_ts

# %%
(
    xs_tr, ys_tr,
    xs_vl, ys_vl,
    xs_ts, ys_ts
) = split_dataset(xs, ys)

# %%
xs_tr.shape, xs_vl.shape, xs_ts.shape
# Out:
# (torch.Size([182516, 3]), torch.Size([22814, 3]), torch.Size([22816, 3]))

# %%
xs_tr.shape[0] + xs_vl.shape[0] + xs_ts.shape[0] == xs.shape[0]
# Out:
# True

# %% [markdown]
# #### Architecture

# %%
g = torch.Generator()
g.manual_seed(1777213731)

# %%
import functools
import operator

gain_linear = 1
gain_tanh   = 5/3

C = torch.randn((VOC_SIZE, EMB_SIZE), dtype=torch.float32, generator=g)
C *= (gain_linear / ((VOC_SIZE)**0.5))

W1 = torch.randn((SEQ_SIZE * EMB_SIZE, HID_SIZE), dtype=torch.float32, generator=g)  # controls gradients flow after activation function
W1 *= (gain_tanh / ((SEQ_SIZE * EMB_SIZE)**0.5))
# b1 = torch.randn(HID_SIZE, dtype=torch.float32)                                    # removed from nn as batch norm layer substitutes bias
# b1 *= 0

epsilon = 1e-6
momentum = 1e-3
bn_running_mean = torch.zeros((1, HID_SIZE), dtype=torch.float32)
bn_running_std = torch.ones((1, HID_SIZE), dtype=torch.float32)
bn_gain = torch.ones((1, HID_SIZE), dtype=torch.float32)
bn_bias = torch.zeros((1, HID_SIZE), dtype=torch.float32)

W2 = torch.randn((HID_SIZE, VOC_SIZE), dtype=torch.float32, generator=g)             # controls softmax predictions
W2 *= (gain_linear / ((HID_SIZE * VOC_SIZE)**0.5))
b2 = torch.randn(VOC_SIZE, dtype=torch.float32)
b2 *= 0

parameters = {
    'C': C,
    'W1': W1,
    # 'b1': b1,
    'bn_gain': bn_gain,
    'bn_bias': bn_bias,
    'W2': W2,
    'b2': b2,
}

for parameter in parameters.values():
    parameter.requires_grad = True

total = sum((
    functools.reduce(operator.mul, p.shape)
    for p in parameters.values()
))
total
# Out:
# 12097

# %%
def forward(xs):
    h_pre = C[xs].view(-1, SEQ_SIZE * EMB_SIZE) @ W1
    h_norm = bn_gain * ((h_pre - bn_running_mean) / bn_running_std) + bn_bias
    h_post = h_norm.tanh()
    logits = h_post @ W2 + b2
    return logits

# %% [markdown]
# #### Training

# %%
loss_tr = []
loss_vl = []

# %%
from collections import defaultdict

neuron_to_states = defaultdict(list)
neuron_to_updates = defaultdict(list)

# %%
epochs = 5000
log_every = 100

lrs = torch.linspace(1e-1, 1e-2, epochs)

for epoch in range(1, epochs + 1):
    # mini batch
    batch = torch.randint(0, xs_tr.shape[0], (BCH_SIZE,))
    
    # forward pass
    # logits = forward(xs_tr[batch])
    h_pre = C[xs_tr[batch]].view(-1, SEQ_SIZE * EMB_SIZE) @ W1

    h_mean = h_pre.mean(dim=0, keepdim=True)
    h_std  = h_pre.std(dim=0, keepdim=True)
    h_norm = bn_gain * ((h_pre - h_mean) / (h_std + epsilon)) + bn_bias
    
    with torch.no_grad():
        bn_running_mean = (1 - momentum) * bn_running_mean + momentum * h_mean
        bn_running_std = (1 - momentum) * bn_running_std + momentum * h_std
    
    h_post = h_norm.tanh()
    
    logits = h_post @ W2 + b2
    loss   = F.cross_entropy(logits, ys_tr[batch])
    
    # backward pass
    for parameter in parameters.values():
        parameter.grad = None
    loss.backward()
    loss_tr.append((epoch, loss.item()))

    # optimize
    lr = lrs[epoch - 1]
    for neuron, parameter in parameters.items():
        parameter.data += -lr * parameter.grad
    
    # metadata
    if epoch == 1 or epoch % log_every == 0:
        print(f"epoch[{epoch}] = {loss.item()}")

        # parameters
        for neuron, parameter in parameters.items():
            data = parameter.data.detach().clone()
            grad = parameter.grad.detach().clone()
            
            neuron_to_states[neuron].append((
                0 if epoch == 1 else epoch, 
                data,
                grad
            ))
            neuron_to_updates[neuron].append((
                0 if epoch == 1 else epoch, 
                (lr * (grad.std() / data.std())).log10(),
            ))

        # validation
        with torch.no_grad():
            logits = forward(xs_vl)
            loss   = F.cross_entropy(logits, ys_vl)
            loss_vl.append((epoch, loss.item()))

logits = forward(xs_ts)
loss   = F.cross_entropy(logits, ys_ts)
loss
# Out:
# epoch[1] = 3.2975127696990967
# epoch[100] = 2.435818910598755
# epoch[200] = 2.266308307647705
# epoch[300] = 2.451917886734009
# epoch[400] = 2.309192419052124
# epoch[500] = 2.3133528232574463
# epoch[600] = 2.119858503341675
# epoch[700] = 2.348534345626831
# epoch[800] = 2.240062952041626
# epoch[900] = 2.423597574234009
# epoch[1000] = 2.401148557662964
# epoch[1100] = 2.4404304027557373
# epoch[1200] = 2.31392240524292
# epoch[1300] = 2.191080093383789
# epoch[1400] = 2.338986873626709
# epoch[1500] = 2.352247953414917
# epoch[1600] = 2.3939812183380127
# epoch[1700] = 2.2331161499023438
# epoch[1800] = 2.533738613128662
# epoch[1900] = 2.3514702320098877
# epoch[2000] = 2.237513303756714
# epoch[2100] = 2.3436942100524902
# epoch[2200] = 2.196153402328491
# epoch[2300] = 2.203625202178955
# epoch[2400] = 2.398432493209839
# epoch[2500] = 2.264441728591919
# epoch[2600] = 2.2122766971588135
# epoch[2700] = 2.355114221572876
# epoch[2800] = 2.155956745147705
# epoch[2900] = 2.226393222808838
# epoch[3000] = 2.2134625911712646
# epoch[3100] = 2.08003306388855
# epoch[3200] = 2.3360188007354736
# epoch[3300] = 2.2057693004608154
# epoch[3400] = 2.418179988861084
# epoch[3500] = 2.1625797748565674
# epoch[3600] = 2.241553544998169
# epoch[3700] = 2.5411131381988525
# epoch[3800] = 2.3666014671325684
# epoch[3900] = 2.112431049346924
# epoch[4000] = 2.2192862033843994
# epoch[4100] = 2.0528130531311035
# epoch[4200] = 2.2098426818847656
# epoch[4300] = 2.1758716106414795
# epoch[4400] = 2.0867931842803955
# epoch[4500] = 2.2415452003479004
# epoch[4600] = 2.023472547531128
# epoch[4700] = 2.1638240814208984
# epoch[4800] = 2.262613534927368
# epoch[4900] = 2.0541436672210693
# epoch[5000] = 2.224745512008667
# tensor(2.4515, grad_fn=<NllLossBackward0>)

# %%
epochs_tr = [e for e, l in loss_tr]
losses_tr = [l for e, l in loss_tr]

epochs_vl = [e for e, l in loss_vl]
losses_vl = [l for e, l in loss_vl]

plt.title("Loss oscilation per split")
plt.plot(epochs_tr, losses_tr, label="Train loss")
plt.plot(epochs_vl, losses_vl, label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ##### Weights' gradients

# %%
for neuron, states in neuron_to_states.items():
    epochs = [
        e
        for e, d, g in states
    ]
    data = [
        g.flatten().mean()
        for e, d, g in states
    ]
    plt.plot(epochs, data, label=neuron)
plt.title("Mean oscilation of weights' gradients")
plt.tight_layout()
plt.legend()
plt.show()

# %%
from ipywidgets import interact, IntSlider, Dropdown

def plot_grad_hist(epoch, neuron, bins):
    plt.figure(figsize=(6, 4))
    
    states = neuron_to_states.get(neuron, [])
    state = next((state for state in states if state[0] == epoch), None)
    
    if state is None:
        print("No data for this epoch/neuron")
        return
    
    data, grad = state[1], state[2]
    if grad is not None:
        plt.hist(grad.flatten(), bins=bins, alpha=0.7)
    
    plt.title(f"Observing: neuron={neuron} | epoch={epoch}")
    plt.xlabel("Gradient")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

neurons = list(neuron_to_states.keys())
max_epoch = max(p[0] for pairs in neuron_to_states.values() for p in pairs)

interact(
    plot_grad_hist,
    epoch=IntSlider(min=0, max=max_epoch, step=log_every, value=1),
    neuron=Dropdown(options=neurons, value=neurons[0]),
    bins=IntSlider(min=5, max=100, step=5, value=25)
)
# Out:
# interactive(children=(IntSlider(value=1, description='epoch', max=5000, step=100), Dropdown(description='neuro…
# <function __main__.plot_grad_hist(epoch, neuron, bins)>

# %% [markdown]
# ##### Weights' data

# %%
for neuron, states in neuron_to_states.items():
    epochs = [
        e 
        for e, d, g in states
    ]
    data = [
        d.flatten().mean()
        for e, d, g in states
    ]
    plt.plot(epochs, data, label=neuron)
plt.title("Mean oscilation of weights' data")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# /var/folders/rp/5xgdthw53sn2b8gbxv7b0r240000gp/T/ipykernel_67006/716912944.py:12: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
from ipywidgets import interact, IntSlider, Dropdown

def plot_data_hist(epoch, neuron, bins):
    plt.figure(figsize=(6, 4))
    
    states = neuron_to_states.get(neuron, [])
    state = next((state for state in states if state[0] == epoch), None)
    
    if state is None:
        print("No data for this epoch/neuron")
        return
    
    data, grad = state[1], state[2]
    if data is not None:
        plt.hist(data.flatten(), bins=bins, alpha=0.7)
    
    plt.title(f"Observing: neuron={neuron} | epoch={epoch}")
    plt.xlabel("Data")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

neurons = list(neuron_to_states.keys())
max_epoch = max(p[0] for pairs in neuron_to_states.values() for p in pairs)

interact(
    plot_data_hist,
    epoch=IntSlider(min=0, max=max_epoch, step=log_every, value=1),
    neuron=Dropdown(options=neurons, value=neurons[0]),
    bins=IntSlider(min=0, max=100, step=5, value=25)
)
# Out:
# interactive(children=(IntSlider(value=1, description='epoch', max=5000, step=100), Dropdown(description='neuro…
# <function __main__.plot_data_hist(epoch, neuron, bins)>

# %% [markdown]
# ##### Weights' grad:data

# %%
from ipywidgets import interact, IntSlider, Dropdown

def plot_ratio_hist(epoch, neuron, bins):
    plt.figure(figsize=(6, 4))
    
    states = neuron_to_states.get(neuron, [])
    state = next((state for state in states if state[0] == epoch), None)
    
    if state is None:
        print("No data for this epoch/neuron")
        return
    
    data, grad = state[1], state[2]
    if data is not None and grad is not None:
        plt.hist((grad.flatten() / data.flatten()), bins=bins, alpha=0.7)
    
    plt.title(f"Observing: neuron={neuron} | epoch={epoch}")
    plt.xlabel("Ratio")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

neurons = list(neuron_to_states.keys())
max_epoch = max(p[0] for pairs in neuron_to_states.values() for p in pairs)

interact(
    plot_ratio_hist,
    epoch=IntSlider(min=0, max=max_epoch, step=log_every, value=1),
    neuron=Dropdown(options=neurons, value=neurons[0]),
    bins=IntSlider(min=0, max=100, step=5, value=25)
)
# Out:
# interactive(children=(IntSlider(value=1, description='epoch', max=5000, step=100), Dropdown(description='neuro…
# <function __main__.plot_ratio_hist(epoch, neuron, bins)>

# %%
for neuron, updates in neuron_to_updates.items():
    epochs, ratios = [], []
    for e, update in updates:
        epochs.append(e)
        ratios.append(update)
    plt.plot(epochs, ratios, label=neuron)
plt.plot(epochs, -3 * torch.ones(len(epochs)), label="Target threshold of grad:data ratio", color="black")
plt.title("Standard deviation of oscilation of weights' grad:data")
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# #### Inference

# %%
gen_names = []
for _ in range(10):
    gen_name = ''.join([CHAR_SEP] * SEQ_SIZE)
    while True:
        xs = torch.tensor([c2i[c] for c in gen_name[-SEQ_SIZE:]])
        with torch.no_grad():
            logits = forward(xs)
        probs = torch.softmax(logits, dim=1)
        i = torch.multinomial(probs, 1,  replacement=True, generator=g).item()
        c = i2c[i]
        if c == CHAR_SEP:
            gen_names.append(gen_name[SEQ_SIZE:])
            break
        gen_name += c
gen_names
# Out:
# ['kimi',
#  'fira',
#  'len',
#  'jamian',
#  'raiyah',
#  'keslan',
#  'laqex',
#  'damith',
#  'noc',
#  'bubrie']

# %% [markdown]
# #### Evaluation

# %%
from tqdm import tqdm

nll = 0.0
count = 0
for name in tqdm(names):
    chars_seq = ''.join([CHAR_SEP] * SEQ_SIZE)
    evals_name = f"{chars_seq}{name}{CHAR_SEP}"
    xs = torch.tensor([[c2i[c] for c in evals_name[i-SEQ_SIZE:i]] for i in range(SEQ_SIZE, len(evals_name))])
    ys = torch.tensor([c2i[evals_name[i]] for i in range(SEQ_SIZE, len(evals_name))])
    with torch.no_grad():
        logits = forward(xs)
        nll += F.cross_entropy(logits, ys)
    count += 1
nll / count
# Out:
# 100%|███████████████████████████████████| 32033/32033 [00:04<00:00, 6923.35it/s]
# tensor(2.2654)
