# %%
import numpy as np 
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F

# %%
with open('names.txt', 'r') as f:
    names = f.read().splitlines()
    chars = sorted(set((char for name in names for char in name)))

# %%
CHAR_SEP = '.'

# %%
SEQ_SIZE = 3
VOC_SIZE = 27
EMB_SIZE = 10
HID_SIZE = 200
BCH_SIZE = 128

# %%
i2c    = {i: c for i, c in enumerate(chars, 1)}
i2c[0] = CHAR_SEP
c2i    = {c: i for i, c in i2c.items()}

# %%
def get_dataset(sequence_size: int = 3, verbose=True):
    xs = []
    ys = []
    
    for i, name in enumerate(names):
        if verbose:
            print(f"name[{i}]: {name}")
        name += CHAR_SEP
        x = ''.join([CHAR_SEP] * SEQ_SIZE)
        for j in range(len(name)):
            y = name[j]
            xs.append([c2i[c] for c in x])
            ys.append(c2i[y])
            if verbose:
                print(f"{x} -> {y}")
            x = f"{x[1:]}{name[j]}"
    
    return torch.tensor(xs), torch.tensor(ys)

xs, ys = get_dataset(SEQ_SIZE, verbose=False)
xs.shape
# Out:
# torch.Size([228146, 3])

# %%
def split_dataset(xs, ys, tr=0.8, vl=0.1, ts=0.1):
    assert len(xs) == len(ys)
    assert abs(tr + vl + ts - 1.0) < 1e-6

    n = len(xs)

    n_tr = int(tr * n)
    n_vl = int(vl * n)

    xs_tr = xs[:n_tr]
    ys_tr = ys[:n_tr]

    xs_vl = xs[n_tr:n_tr + n_vl]
    ys_vl = ys[n_tr:n_tr + n_vl]

    xs_ts = xs[n_tr + n_vl:]
    ys_ts = ys[n_tr + n_vl:]

    return xs_tr, ys_tr, xs_vl, ys_vl, xs_ts, ys_ts

# %%
(
    xs_tr, ys_tr,
    xs_vl, ys_vl,
    xs_ts, ys_ts
) = split_dataset(xs, ys)

# %%
xs_tr.shape, xs_vl.shape, xs_ts.shape
# Out:
# (torch.Size([182516, 3]), torch.Size([22814, 3]), torch.Size([22816, 3]))

# %%
xs_tr.shape[0] + xs_vl.shape[0] + xs_ts.shape[0] == xs.shape[0]
# Out:
# True

# %% [markdown]
# #### Architecture

# %%
g = torch.Generator()
g.manual_seed(1777213731)

# %%
import functools
import operator

C = torch.randn((VOC_SIZE, EMB_SIZE), dtype=torch.float32, generator=g)
C *= ((1) / (VOC_SIZE)**0.5)

W1 = torch.randn((SEQ_SIZE * EMB_SIZE, HID_SIZE), dtype=torch.float32, generator=g)  # controls gradients flow after activation function
W1 *= ((5/3) / (SEQ_SIZE * EMB_SIZE)**0.5)
# b1 = torch.randn(HID_SIZE, dtype=torch.float32)                                    # removed from nn as batch norm layer substitutes bias
# b1 *= 0

epsilon = 1e-6
momentum = 1e-3
bn_running_mean = torch.zeros((1, HID_SIZE), dtype=torch.float32)
bn_running_std = torch.ones((1, HID_SIZE), dtype=torch.float32)
bn_gain = torch.ones((1, HID_SIZE), dtype=torch.float32)
bn_bias = torch.zeros((1, HID_SIZE), dtype=torch.float32)

W2 = torch.randn((HID_SIZE, VOC_SIZE), dtype=torch.float32, generator=g)             # controls softmax predictions
W2 *= ((1) / (HID_SIZE * VOC_SIZE)**0.5)
b2 = torch.randn(VOC_SIZE, dtype=torch.float32)
b2 *= 0

parameters = {
    'C': C,
    'W1': W1,
    # 'b1': b1,
    'bn_gain': bn_gain,
    'bn_bias': bn_bias,
    'W2': W2,
    'b2': b2,
}

for parameter in parameters.values():
    parameter.requires_grad = True

total = sum((
    functools.reduce(operator.mul, p.shape)
    for p in parameters.values()
))
total
# Out:
# 12097

# %%
def forward(xs):
    h_pre = C[xs].view(-1, SEQ_SIZE * EMB_SIZE) @ W1
    h_norm = bn_gain * ((h_pre - bn_running_mean) / bn_running_std) + bn_bias
    h_post = h_norm.tanh()
    logits = h_post @ W2 + b2
    return logits

# %% [markdown]
# #### Training

# %%
loss_tr = []
loss_vl = []

# %%
from collections import defaultdict

neuron_to_states = defaultdict(list)

for neuron, parameter in parameters.items():
    neuron_to_states[neuron].append((
        0,
        parameter.data.detach().cpu().flatten().tolist(),
        parameter.grad.detach().cpu().flatten().tolist() if parameter.grad else None
    ))
neuron_to_states['h_pre'].append((0, None, None))
neuron_to_states['h_post'].append((0, None, None))

# %%
epochs = 10000
log_every = 100

lrs = torch.linspace(1, 0, epochs)

for epoch in range(1, epochs + 1):
    # mini batch
    batch = torch.randint(0, xs_tr.shape[0], (BCH_SIZE,))
    
    # forward pass
    # logits = forward(xs_tr[batch])
    h_pre = C[xs_tr[batch]].view(-1, SEQ_SIZE * EMB_SIZE) @ W1
    h_pre.retain_grad()

    h_mean = h_pre.mean(dim=0, keepdim=True)
    h_std  = h_pre.std(dim=0, keepdim=True)
    h_norm = bn_gain * ((h_pre - h_mean) / (h_std + epsilon)) + bn_bias
    
    with torch.no_grad():
        bn_running_mean = (1 - momentum) * bn_running_mean + momentum * h_mean
        bn_running_std = (1 - momentum) * bn_running_std + momentum * h_std
    
    h_post = h_norm.tanh()
    h_post.retain_grad()
    
    logits = h_post @ W2 + b2
    loss   = F.cross_entropy(logits, ys_tr[batch])
    
    # backward pass
    for parameter in parameters.values():
        parameter.grad = None
    loss.backward()
    loss_tr.append((epoch, loss.item()))

    # optimize
    lr = lrs[epoch - 1]
    for neuron, parameter in parameters.items():
        parameter.data += -lr * parameter.grad
    
    # metadata
    if epoch == 1 or epoch % log_every == 0:
        print(f"epoch[{epoch}] = {loss.item()}")

        # parameters
        for neuron, parameter in parameters.items():
            neuron_to_states[neuron].append((
                0 if epoch == 1 else epoch, 
                parameter.data.detach().cpu().flatten().tolist(),
                parameter.grad.detach().cpu().flatten().tolist()
            ))
        neuron_to_states['h_pre'].append((
            0 if epoch == 1 else epoch,
            h_pre.data.detach().cpu().flatten().tolist(),
            h_pre.grad.detach().cpu().flatten().tolist()
        ))
        neuron_to_states['h_post'].append((
            0 if epoch == 1 else epoch,
            h_post.data.detach().cpu().flatten().tolist(),
            h_post.grad.detach().cpu().flatten().tolist()
        ))

        # validation
        with torch.no_grad():
            logits = forward(xs_vl)
            loss   = F.cross_entropy(logits, ys_vl)
            loss_vl.append((epoch, loss.item()))

logits = forward(xs_ts)
loss   = F.cross_entropy(logits, ys_ts)
loss
# Out:
# epoch[1] = 3.2894413471221924
# epoch[100] = 2.3023908138275146
# epoch[200] = 2.401522397994995
# epoch[300] = 2.162161111831665
# epoch[400] = 2.3764591217041016
# epoch[500] = 2.635493516921997
# epoch[600] = 2.541630506515503
# epoch[700] = 2.2671945095062256
# epoch[800] = 2.3201146125793457
# epoch[900] = 2.348304033279419
# epoch[1000] = 2.3341851234436035
# epoch[1100] = 2.1846840381622314
# epoch[1200] = 2.1657469272613525
# epoch[1300] = 2.519597053527832
# epoch[1400] = 2.296238899230957
# epoch[1500] = 2.4077751636505127
# epoch[1600] = 2.1607658863067627
# epoch[1700] = 2.2490508556365967
# epoch[1800] = 1.9614157676696777
# epoch[1900] = 2.06461238861084
# epoch[2000] = 2.332033395767212
# epoch[2100] = 2.1795854568481445
# epoch[2200] = 2.15561842918396
# epoch[2300] = 2.1770102977752686
# epoch[2400] = 2.1940693855285645
# epoch[2500] = 2.218447685241699
# epoch[2600] = 2.2047364711761475
# epoch[2700] = 2.3116860389709473
# epoch[2800] = 2.250308036804199
# epoch[2900] = 2.315042734146118
# epoch[3000] = 2.1990280151367188
# epoch[3100] = 2.2646114826202393
# epoch[3200] = 2.108520746231079
# epoch[3300] = 2.1469202041625977
# epoch[3400] = 2.2083349227905273
# epoch[3500] = 2.1476423740386963
# epoch[3600] = 2.0870840549468994
# epoch[3700] = 2.200204849243164
# epoch[3800] = 2.330432415008545
# epoch[3900] = 2.097109079360962
# epoch[4000] = 2.249161720275879
# epoch[4100] = 2.1199533939361572
# epoch[4200] = 2.2126054763793945
# epoch[4300] = 2.1783437728881836
# epoch[4400] = 2.3246073722839355
# epoch[4500] = 2.134943723678589
# epoch[4600] = 2.090712785720825
# epoch[4700] = 2.207315444946289
# epoch[4800] = 2.122354745864868
# epoch[4900] = 2.103889226913452
# epoch[5000] = 2.0641634464263916
# epoch[5100] = 2.2971363067626953
# epoch[5200] = 2.345867395401001
# epoch[5300] = 2.1524741649627686
# epoch[5400] = 2.0995864868164062
# epoch[5500] = 1.9933208227157593
# epoch[5600] = 2.0269625186920166
# epoch[5700] = 2.177905797958374
# epoch[5800] = 2.1479601860046387
# epoch[5900] = 2.0760483741760254
# epoch[6000] = 2.1927318572998047
# epoch[6100] = 2.0067942142486572
# epoch[6200] = 2.278592824935913
# epoch[6300] = 2.3061978816986084
# epoch[6400] = 2.328700065612793
# epoch[6500] = 2.1284310817718506
# epoch[6600] = 2.15509295463562
# epoch[6700] = 2.159806966781616
# epoch[6800] = 2.1014208793640137
# epoch[6900] = 2.0074474811553955
# epoch[7000] = 2.108198642730713
# epoch[7100] = 2.0085456371307373
# epoch[7200] = 2.363415002822876
# epoch[7300] = 2.286022663116455
# epoch[7400] = 2.085451126098633
# epoch[7500] = 2.0034186840057373
# epoch[7600] = 2.0489063262939453
# epoch[7700] = 2.220933198928833
# epoch[7800] = 2.1856560707092285
# epoch[7900] = 2.0890145301818848
# epoch[8000] = 2.043487310409546
# epoch[8100] = 2.0618932247161865
# epoch[8200] = 2.0832812786102295
# epoch[8300] = 2.0335700511932373
# epoch[8400] = 2.0445921421051025
# epoch[8500] = 2.030311107635498
# epoch[8600] = 2.0712687969207764
# epoch[8700] = 2.1883606910705566
# epoch[8800] = 2.21421480178833
# epoch[8900] = 2.200202703475952
# epoch[9000] = 2.0770254135131836
# epoch[9100] = 2.0800211429595947
# epoch[9200] = 2.303713321685791
# epoch[9300] = 2.090022325515747
# epoch[9400] = 2.0139834880828857
# epoch[9500] = 2.2415008544921875
# epoch[9600] = 2.1503067016601562
# epoch[9700] = 2.297943592071533
# epoch[9800] = 2.235814332962036
# epoch[9900] = 2.0799970626831055
# epoch[10000] = 2.0103585720062256
# tensor(2.3793, grad_fn=<NllLossBackward0>)

# %%
epochs_tr = [e for e, l in loss_tr]
losses_tr = [l for e, l in loss_tr]

epochs_vl = [e for e, l in loss_vl]
losses_vl = [l for e, l in loss_vl]

plt.title("Loss oscilation per split")
plt.plot(epochs_tr, losses_tr, label="Train loss")
plt.plot(epochs_vl, losses_vl, label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ##### Weights' gradients

# %%
for neuron, parameters in neuron_to_states.items():
    epochs = [e for e, d, g in parameters]
    data = [np.mean(g) if g else 0.0 for e, d, g in parameters]
    plt.plot(epochs, data, label=neuron)
plt.title("Mean oscilation of weights' gradients")
plt.tight_layout()
plt.legend()
plt.show()

# %%
from ipywidgets import interact, IntSlider, Dropdown

def plot_grad_hist(epoch, neuron, bins):
    plt.figure(figsize=(6, 4))
    
    states = neuron_to_states.get(neuron, [])
    state = next((state for state in states if state[0] == epoch), None)
    
    if state is None:
        print("No data for this epoch/neuron")
        return
    
    data, grad = state[1], state[2]
    if grad is not None:
        plt.hist(grad, bins=bins, alpha=0.7)
    
    plt.title(f"Observing: neuron={neuron} | epoch={epoch}")
    plt.xlabel("Gradient")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

neurons = list(neuron_to_states.keys())
max_epoch = max(p[0] for pairs in neuron_to_states.values() for p in pairs)

interact(
    plot_grad_hist,
    epoch=IntSlider(min=0, max=max_epoch, step=log_every, value=1),
    neuron=Dropdown(options=neurons, value=neurons[0]),
    bins=IntSlider(min=5, max=100, step=5, value=25)
)
# Out:
# interactive(children=(IntSlider(value=1, description='epoch', max=10000, step=100), Dropdown(description='neur…
# <function __main__.plot_grad_hist(epoch, neuron, bins)>

# %% [markdown]
# ##### Weights' data

# %%
for neuron, parameters in neuron_to_states.items():
    epochs = [e for e, d, g in parameters]
    data = [np.mean(d) if d else 0.0 for e, d, g in parameters]
    plt.plot(epochs, data, label=neuron)
plt.title("Mean oscilation of weights' data")
plt.tight_layout()
plt.legend()
plt.show()

# %%
from ipywidgets import interact, IntSlider, Dropdown

def plot_data_hist(epoch, neuron, bins):
    plt.figure(figsize=(6, 4))
    
    states = neuron_to_states.get(neuron, [])
    state = next((state for state in states if state[0] == epoch), None)
    
    if state is None:
        print("No data for this epoch/neuron")
        return
    
    data, grad = state[1], state[2]
    if data is not None:
        plt.hist(data, bins=bins, alpha=0.7)
    
    plt.title(f"Observing: neuron={neuron} | epoch={epoch}")
    plt.xlabel("Data")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

neurons = list(neuron_to_states.keys())
max_epoch = max(p[0] for pairs in neuron_to_states.values() for p in pairs)

interact(
    plot_data_hist,
    epoch=IntSlider(min=0, max=max_epoch, step=log_every, value=1),
    neuron=Dropdown(options=neurons, value=neurons[0]),
    bins=IntSlider(min=0, max=100, step=5, value=25)
)
# Out:
# interactive(children=(IntSlider(value=1, description='epoch', max=10000, step=100), Dropdown(description='neur…
# <function __main__.plot_data_hist(epoch, neuron, bins)>

# %% [markdown]
# #### Inference

# %%
gen_names = []
for _ in range(10):
    gen_name = ''.join([CHAR_SEP] * SEQ_SIZE)
    while True:
        xs = torch.tensor([c2i[c] for c in gen_name[-SEQ_SIZE:]])
        with torch.no_grad():
            logits = forward(xs)
        probs = torch.softmax(logits, dim=1)
        i = torch.multinomial(probs, 1,  replacement=True, generator=g).item()
        c = i2c[i]
        if c == CHAR_SEP:
            gen_names.append(gen_name[SEQ_SIZE:])
            break
        gen_name += c
gen_names
# Out:
# ['kimberia',
#  'monie',
#  'javan',
#  'raiyah',
#  'kesley',
#  'lakextyseron',
#  'nochuanrie',
#  'mai',
#  'akdael',
#  'tamoja']

# %% [markdown]
# #### Evaluation

# %%
from tqdm import tqdm

nll = 0.0
count = 0
for name in tqdm(names):
    chars_seq = ''.join([CHAR_SEP] * SEQ_SIZE)
    evals_name = f"{chars_seq}{name}{CHAR_SEP}"
    xs = torch.tensor([[c2i[c] for c in evals_name[i-SEQ_SIZE:i]] for i in range(SEQ_SIZE, len(evals_name))])
    ys = torch.tensor([c2i[evals_name[i]] for i in range(SEQ_SIZE, len(evals_name))])
    with torch.no_grad():
        logits = forward(xs)
        nll += F.cross_entropy(logits, ys)
    count += 1
nll / count
# Out:
# 100%|███████████████████████████████████| 32033/32033 [00:05<00:00, 6284.90it/s]
# tensor(2.1636)
